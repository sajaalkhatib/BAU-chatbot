# %%
from tkinter import * #importing all the functions and methods
from tkinter import ttk, PhotoImage, Label
from tkinter.ttk import Progressbar #import the progress bar widget from the ttk module in the Tkinter library.
import sys #allows you to access system-specific parameters and functions in Python
from PIL import ImageTk,Image # loading Python Imaging Library 

# ========================================================================
# ===========================Creat Page===================================
# ========================================================================

root=Toplevel()#creates a new window instance and assigns it to the variable root
root.resizable(0,0)#do not allow resizing

# Define window dimensions
height=500
width=800

# Calculate window position to center it on the screen
x=(root.winfo_screenwidth()//2)-(width//2)
y=(root.winfo_screenheight()//2)-(height//2)

# Set window geometry (size and position)
root.geometry('{}x{}+{}+{}'.format(width, height, x, y))

root.wm_attributes('-topmost',True)# Make the window appear on top of other windows
root.wm_attributes('-alpha',0.8)#Set window transparency (alpha value)

#Hide borders and title bar
root.overrideredirect(1)

root.config(background= '#45aaf2')

# ========================================================================
# ========================Creat Exit Button===============================
# ========================================================================

exit_btn= Button(root, text='X', command=lambda: exit_window(),fg='yellow', bg='#45aaf2',bd=0, 
                 activebackground='#FFFFFF',font=("yu gothic ui", 13, 'bold'))
exit_btn.place(x=775,y=0)
welcome_lable = Label(root, text= "Welcom To Intelligent Chatbot", font=("yu gothic ui", 19, 'bold'),fg='black',bg='#45aaf2' )
welcome_lable.place(x=200,y=8)

# ========================================================================
# ======================Add Logo to window================================
# ========================================================================

image= PhotoImage(file='sss.png')
bg_label= Label(root, image=image, bg='#45aaf2' )
bg_label.pack(expand=True)  # This will center the image in the window


# ========================================================================
# =========================Add ProgressBar================================
# ========================================================================

progress_label=Label(root, text= "Please Wait.......", font=("yu gothic ui", 13, 'bold'),fg='black',bg='#45aaf2' )
progress_label.place(x=190,y=380)

progress= Progressbar(root, orient=HORIZONTAL, length=600, mode='determinate')
progress.place(x=60,y=430)
# ========================================================================
# ==========================Exit Function=================================
# ========================================================================

def exit_window(): #Used to terminate the execution of a program
    sys.exit(root.destroy()) #To close or remove the user interface window

def top():
    win= Toplevel()
    loginpage.LoginPage(win)
    root.withdraw()
    win.deiconify()
    
# ========================================================================    
# =================Function to go to the Login Page=======================
# ======================================================================== 

def login_page():
    
    root.destroy()
    # %run LoginPage.ipynb

# ========================================================================
# ==================Function to Load the ProgressBar======================
# ========================================================================

i=0

def load():
    global i
    if i<=10:
        txt='Please Wait...'+ (str(10*i)+'%')
        progress_label.config(text=txt)
        progress_label.after(1000, load)
        progress['value']=10*i
        i+=1
    else:
        login_page()
        
load()
root.mainloop()
# Out:
# saja
# saja
# saja
# 5
# historychat_chatnu: 6
# saja
# 5
# historychat_chatnu: 6
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_21608\1098508195.py", line 68, in connect_database
#     home_page(email,usename)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_21608\1098508195.py", line 21, in home_page
#     root.destroy()
#   File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 2656, in destroy
#     self.tk.call('destroy', self._w)
# _tkinter.TclError: can't invoke "destroy" command: application has been destroyed
