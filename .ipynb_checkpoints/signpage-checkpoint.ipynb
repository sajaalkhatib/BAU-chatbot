# %%
from tkinter import *
from tkinter import messagebox
from PIL import ImageTk, Image
import pymysql
import import_ipynb
import sys

def login_page():
    window .destroy()
    # %run LoginPage.ipynb

def clear():
    email_entry.delete(0,END)
    username_entry.delete(0,END)
    password_entry.delete(0,END)
    
    
def connect_database():
    if email_entry.get()=='' or password_entry.get()=='':
        messagebox.showerror('Error','All Fields Are Required')
    emailfeild= email_entry.get()
    if not emailfeild.endswith("@bau.edu.jo"):
            messagebox.showerror('Error','The Email should be from Albalqa University')     
    else:
        try:
            con=pymysql.connect(host='localhost',user='root',password='saja2001')
            mycursor=con.cursor()
        except:
            messagebox.showerror('Error','Database Connectivity Issue, Please Try Again')
            return
        try:
            query='create database user'
            mycursor.execute(query)
            query='use user'
            mycursor.execute(query)
            query='create table data(id int auto_increment primary key not null, email varchar(50),username varchar(100),password varchar(20))'
            mycursor.execute(query)
        except:
            mycursor.execute('use user')
            query= 'select * from data where email=%s'
            mycursor.execute(query,(email_entry.get()))
            
            row=mycursor.fetchone()
            if row !=None:
                messagebox.showerror('Error','Email Already Exists')
            else:
                mycursor.execute('use user')
                query= 'insert into data(email,username,password) values(%s,%s,%s)'
                mycursor.execute(query,(email_entry.get(),username_entry.get(),password_entry.get()))
                con.commit()
                con.close()
                messagebox.showinfo('Success','Registration is succesful')
                clear()
                login_page()
def show():
    hide_button = Button(lgn_frame, image=hide_image, command=hide, relief=FLAT,
                                  activebackground="white"
                                  , borderwidth=0, background="white", cursor="hand2")
    hide_button.place(x=860, y=400)
    password_entry.config(show='')

        
def hide():
    show_button = Button(lgn_frame, image=show_image, command=show, relief=FLAT,
                                  activebackground="white"
                                  , borderwidth=0, background="white", cursor="hand2")
    show_button.place(x=860, y=400)
    password_entry.config(show='*')
    

# method to start the main event loop and display the GUI
window= Toplevel()
# ========================================================================
# ============================background image============================
# ========================================================================
        
bg_frame = Image.open('aa.png')
bg_photo = ImageTk.PhotoImage(bg_frame)
bg_panel = Label(window, image=bg_photo)
bg_panel.image = bg_photo
bg_panel.pack(fill='both', expand='yes')
# ====== Sign Frame =========================
        
lgn_frame = Frame(window, bg='#636ef7', width=950, height=600)
lgn_frame.place(x=200, y=70)
        
# ========================================================================
# ========================================================================
        
txt = "WELCOME"
heading = Label(lgn_frame, text=txt, font=('yu gothic ui', 25, "bold"), bg="#636ef7",
                             fg='white',bd=5,relief=FLAT)
heading.place(x=80, y=30, width=300, height=30)

 # ========================================================================
# ============ Left Side Image ================================================
# ========================================================================
              
side_image = Image.open('vector.png')
side_photo = ImageTk.PhotoImage(side_image)
side_image_label = Label(lgn_frame, image=side_photo, bg='#636ef7')
side_image_label.image = side_photo
side_image_label.place(x=5, y=100)
               
# ========================================================================
# ============ Sign up Image =============================================
# ========================================================================
        
sign_in_image = Image.open('hyy.png')
sign_in_photo = ImageTk.PhotoImage(sign_in_image)
sign_in_image_label = Label(lgn_frame, image=sign_in_photo, bg='#636ef7')
sign_in_image_label.image = sign_in_photo
sign_in_image_label.place(x=620, y=50)            
# ========================================================================
# ============ Sign up label =============================================
# ========================================================================
        
sign_in_label = Label(lgn_frame, text="Sign Up", bg="#636ef7", fg="white",font=("yu gothic ui", 17, "bold"))
sign_in_label.place(x=650, y=160)
# ========================================================================
# ============================Email=======================================
# ========================================================================
        
username_label = Label(lgn_frame, text="Email", bg="#636ef7", fg="white",
                                    font=("yu gothic ui", 13, "bold"))
username_label.place(x=550, y=220)
email_entry= Entry(lgn_frame, highlightthickness=0, relief=FLAT, bg="#636ef7", fg="white",
                                font=("yu gothic ui ", 12, "bold"), insertbackground = 'white')
email_entry.place(x=580, y=250, width=270)

username_line = Canvas(lgn_frame, width=300, height=2.0, bg="white", highlightthickness=0)
username_line.place(x=550, y=280)
        
# ===== Email icon =========
        
username_icon = Image.open('username_icon.png')
username_photo = ImageTk.PhotoImage(username_icon)
username_icon_label = Label(lgn_frame, image=username_photo, bg='#636ef7')
username_icon_label.image = username_photo
username_icon_label.place(x=550, y=250)
# ========================================================================
# ============================username====================================
# ========================================================================
        
username_label = Label(lgn_frame, text="Username", bg="#636ef7", fg="white",
                                    font=("yu gothic ui", 13, "bold"))
username_label.place(x=550, y=300)

username_entry = Entry(lgn_frame, highlightthickness=0, relief=FLAT, bg="#636ef7", fg="white",
                                    font=("yu gothic ui ", 12, "bold"), insertbackground = 'white')
username_entry.place(x=580, y=330, width=270)

username_line = Canvas(lgn_frame, width=300, height=2.0, bg="white", highlightthickness=0)
username_line.place(x=550, y=360)
        
# ===== Username icon =========
        
email_icon = Image.open('username_icon.png')
email_photo = ImageTk.PhotoImage(username_icon)
username_icon_label = Label(lgn_frame, image=email_photo, bg='#636ef7')
username_icon_label.image = email_photo
username_icon_label.place(x=550, y=330)

# ========================================================================
# ============================login button================================
# ========================================================================
        
lgn_button = Image.open('btn1.png')
lgn_photo = ImageTk.PhotoImage(lgn_button)
lgn_button_label = Label(lgn_frame, image=lgn_photo, bg='#636ef7')
lgn_button_label.image = lgn_photo
lgn_button_label.place(x=550, y=450)
login = Button(lgn_button_label, text='SignUp', font=("yu gothic ui", 13, "bold"), width=25, bd=0,
                            bg='#3047ff', cursor='hand2', activebackground='#636ef7', fg='white',command=connect_database)
login.place(x=20, y=10)
        
# =========== Sign In ==================================================
        
sign_label = Label(lgn_frame, text='You have already account?', font=("yu gothic ui", 11, "bold"),
                                relief=FLAT, borderwidth=0, background="#636ef7", fg='white')
sign_label.place(x=550, y=535)
        
signup_img = Image.open('btn4.png')
photo2 = ImageTk.PhotoImage(signup_img)
signup_button_label = Label(lgn_frame, image=photo2, bg='#636ef7')
signup_button_label.image = photo2
        
signup_button_label.place(x=750, y=535, width=165, height=26)
sign=Button(signup_button_label, text='Login', font=("yu gothic ui", 10, "bold"), width=15,height=1, bd=0,
                            bg='#3047ff', cursor='hand2', activebackground='#636ef7', fg='white',command=login_page)
        
sign.place(x=20, y=1)

# ========================================================================
# ============================password====================================
# ========================================================================
        
password_label = Label(lgn_frame, text="Password", bg="#636ef7", fg="white",
                                    font=("yu gothic ui", 13, "bold"))
password_label.place(x=550, y=370)

password_entry = Entry(lgn_frame, highlightthickness=0, relief=FLAT, bg="#636ef7", fg="white",
                                    font=("yu gothic ui", 12, "bold"), show="*", insertbackground = 'white')
password_entry.place(x=580, y=400, width=244)

password_line = Canvas(lgn_frame, width=300, height=2.0, bg="white", highlightthickness=0)
password_line.place(x=550, y=430)
        
# ======== Password icon ================
password_icon = Image.open('password_icon.png')
photo = ImageTk.PhotoImage(password_icon)
password_icon_label = Label(lgn_frame, image=photo, bg='#636ef7')
password_icon_label.image = photo
password_icon_label.place(x=550, y=400)
        
# ========= show/hide password ==================================================================
        
show_image = ImageTk.PhotoImage \
            (file='show.png')

hide_image = ImageTk.PhotoImage \
            (file='hide.png')
hide_button = Button(lgn_frame, image=hide_image, command=hide, relief=FLAT,
                                  activebackground="white"
                                  , borderwidth=0, background="white", cursor="hand1")
hide_button.place(x=860, y=400)

   

window.mainloop()
# Out:
# saja
# saja
# saja
# 1
# historychat_chatnu: 2
# 1
# saja
# 3
# historychat_chatnu: 4
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# [{'intent': 'greeting', 'probability': '0.35697705'}]
# greeting
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# [{'intent': 'greeting', 'probability': '0.35697705'}]
# greeting
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# [{'intent': 'objection ', 'probability': '0.950828'}]
# objection
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# [{'intent': 'thanks', 'probability': '0.25941914'}]
# thanks
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001E30E57B7E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001E30E57B7E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# [{'intent': 'objection ', 'probability': '0.950828'}]
# objection
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001E30E579260> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001E30E579260> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# [{'intent': 'objection ', 'probability': '0.64490455'}]
# objection
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# [{'intent': 'closed_sections', 'probability': '0.9999443'}]
# closed_sections
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# [{'intent': 'closed_sections', 'probability': '0.9999443'}]
# closed_sections
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# [{'intent': 'closed_sections', 'probability': '0.99675226'}]
# closed_sections
# saja
# 3
# historychat_chatnu: 4
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9828\1451651964.py", line 33, in connect_database
#     mycursor.execute(query)
#   File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py", line 153, in execute
#     result = self._query(query)
#              ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py", line 322, in _query
#     conn.query(q)
#   File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py", line 558, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py", line 822, in _read_query_result
#     result.read()
#   File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py", line 1200, in read
#     first_packet = self.connection._read_packet()
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py", line 772, in _read_packet
#     packet.raise_for_error()
#   File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.ProgrammingError: (1007, "Can't create database 'user'; database exists")
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9828\1098508195.py", line 68, in connect_database
#     home_page(email,usename)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9828\1098508195.py", line 21, in home_page
#     root.destroy()
#   File "C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 2656, in destroy
#     self.tk.call('destroy', self._w)
# _tkinter.TclError: can't invoke "destroy" command: application has been destroyed
